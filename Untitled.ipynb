# %%
import pandas as pd
meteo = pd.read_csv("meteoItalianProvinces.csv", sep=";")

# %%
len(list(set(meteo.LOCALITA)))
# Out:
# 79

# %%
meteo[meteo.LOCALITA == 'La Spezia']
# Out:
#        LOCALITA       DATA  TMEDIA °C  TMIN °C  TMAX °C  PUNTORUGIADA °C  \
# 5843  La Spezia  1/11/2019        NaN      NaN      NaN              NaN
# 5844  La Spezia  2/11/2019        NaN      NaN      NaN              NaN
# 5845  La Spezia  3/11/2019        NaN      NaN      NaN              NaN
# 5846  La Spezia  4/11/2019       17.0     12.0     19.0             15.0
# 5847  La Spezia  5/11/2019       17.0     17.0     18.0             14.0
# ...         ...        ...        ...      ...      ...              ...
# 6072  La Spezia  20/6/2020        NaN      NaN      NaN              NaN
# 6073  La Spezia  21/6/2020        NaN      NaN      NaN              NaN
# 6074  La Spezia  22/6/2020       22.0     17.0     26.0             15.0
# 6075  La Spezia  23/6/2020       25.0     18.0     30.0             15.0
# 6076  La Spezia  24/6/2020       25.0     19.0     27.0             13.0
#
#       UMIDITA %  VISIBILITA km  VENTOMEDIA km/h  VENTOMAX km/h  RAFFICA km/h  \
# ...
